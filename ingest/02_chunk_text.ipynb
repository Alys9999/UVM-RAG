# %%
import sys
import torch

print("Python Version:", sys.version)
print("PyTorch Version:", torch.__version__)
print("CUDA Version (PyTorch):", torch.version.cuda)
print("CUDA Available:", torch.cuda.is_available())
# Out:
# Python Version: 3.13.5 (tags/v3.13.5:6cb20a2, Jun 11 2025, 16:15:46) [MSC v.1943 64 bit (AMD64)]
# PyTorch Version: 2.7.1+cu118
# CUDA Version (PyTorch): 11.8
# CUDA Available: True

# %%
# 02_text_chunk_and_doc_build.ipynb

from pathlib import Path
import json
import hashlib
import re
from datetime import datetime, timezone
from typing import List, Dict, Any, Optional

from haystack.dataclasses import Document
from haystack.components.preprocessors import DocumentSplitter

# %%
# Paths: aligned with 01_5 outputs

ROOT = Path.cwd().parent                  # repo root: .../UVM-RAG
WORK_DIR = ROOT / "work"

# Users Guide
MANUAL_JSON_IN = (
    WORK_DIR
    / "work_manual"
    / "json_out"
    / "uvm_users_guide_blocks_augmented.jsonl"
)
MANUAL_JSON_OUT = (
    WORK_DIR
    / "work_manual"
    / "json_out"
    / "uvm_users_guide_chunks.haystack.jsonl"
)

# Class Reference
CLASS_JSON_IN = (
    WORK_DIR
    / "work_class_reference"
    / "json_out"
    / "uvm_class_reference_blocks_augmented.jsonl"
)
CLASS_JSON_OUT = (
    WORK_DIR
    / "work_class_reference"
    / "json_out"
    / "uvm_class_reference_chunks.haystack.jsonl"
)

# Minimum word count for a text block before we consider it “big enough”.
# Short text rows are accumulated until this threshold is reached.
MIN_TEXT_WORDS = 16

MANUAL_JSON_IN, MANUAL_JSON_OUT, CLASS_JSON_IN, CLASS_JSON_OUT
# Out:
# (WindowsPath('c:/Users/41v1r/NEU/NLP/UVM-RAG/work/work_manual/json_out/uvm_users_guide_blocks_augmented.jsonl'),
#  WindowsPath('c:/Users/41v1r/NEU/NLP/UVM-RAG/work/work_manual/json_out/uvm_users_guide_chunks.haystack.jsonl'),
#  WindowsPath('c:/Users/41v1r/NEU/NLP/UVM-RAG/work/work_class_reference/json_out/uvm_class_reference_blocks_augmented.jsonl'),
#  WindowsPath('c:/Users/41v1r/NEU/NLP/UVM-RAG/work/work_class_reference/json_out/uvm_class_reference_chunks.haystack.jsonl'))

# %%
def load_paragraph_jsonl(path: Path) -> List[Dict[str, Any]]:
    """
    Load block-level JSONL produced by 01_5_toc_mineru_svcode.py.
    Each line is a dict with fields like:
      - type: "text" | "sv_code" | "table" | "image"
      - content (for text/sv_code)
      - table_* / image_* for tables and figures
      - uri, anchor, page_from, page_to, section_title, etc.
    """
    records: List[Dict[str, Any]] = []
    with path.open("r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            records.append(json.loads(line))
    return records


def normalize_text(text: str) -> str:
    """
    Normalize text for checksum: collapse whitespace.
    This does not go back into Document.content; only used for hashing.
    """
    return " ".join(text.split())


def compute_checksum(text: str) -> str:
    norm = normalize_text(text)
    return hashlib.sha1(norm.encode("utf-8")).hexdigest()

# %%
def aggregate_short_text_rows(
    rows: List[Dict[str, Any]],
    min_words: int = MIN_TEXT_WORDS,
) -> List[Dict[str, Any]]:
    """
    Aggregate consecutive 'text' rows so that each aggregated row has at least
    `min_words` words, instead of dropping very short items.

    - Only rows with type == "text" are aggregated.
    - Non-text rows ("table", "image", "sv_code", etc.) are passed through
      and also flush any pending text buffer.
    - page_from/page_to are updated to encompass the merged range.
    """
    aggregated: List[Dict[str, Any]] = []

    buffer_row: Optional[Dict[str, Any]] = None
    buffer_word_count: int = 0

    def flush_buffer() -> None:
        nonlocal buffer_row, buffer_word_count
        if buffer_row is not None:
            aggregated.append(buffer_row)
            buffer_row = None
            buffer_word_count = 0

    for row in rows:
        rtype = row.get("type", "text")

        # Non-text: flush any buffered text and pass through directly
        if rtype != "text":
            flush_buffer()
            aggregated.append(row)
            continue

        text = (row.get("content") or "").strip()
        if not text:
            # empty text row – nothing to aggregate
            continue

        words = text.split()

        if buffer_row is None:
            # start new buffer
            buffer_row = dict(row)  # shallow copy
            buffer_word_count = len(words)
        else:
            # merge into buffer
            buf_text = (buffer_row.get("content") or "").rstrip()
            merged = (buf_text + "\n" + text) if buf_text else text
            buffer_row["content"] = merged

            # update page_from/page_to if present
            pf_old = buffer_row.get("page_from")
            pf_new = row.get("page_from")
            if pf_old is not None and pf_new is not None:
                buffer_row["page_from"] = min(pf_old, pf_new)

            pt_old = buffer_row.get("page_to")
            pt_new = row.get("page_to")
            if pt_old is not None and pt_new is not None:
                buffer_row["page_to"] = max(pt_old, pt_new)

            buffer_word_count += len(words)

        # If threshold is reached, flush this text block
        if buffer_word_count >= min_words:
            flush_buffer()

    # Flush any residual short buffer at the end
    flush_buffer()
    return aggregated

# %%
from copy import deepcopy
from pathlib import PurePosixPath
import re


def html_to_text(html: str) -> str:
    """
    Very lightweight HTML -> text conversion for table bodies.
    This is intentionally simple: strip tags, collapse whitespace.
    """
    if not html:
        return ""
    # remove tags
    text = re.sub(r"<[^>]+>", " ", html)
    # normalize whitespace
    return " ".join(text.split())


def rows_to_paragraph_docs(rows: List[Dict[str, Any]]) -> List[Document]:
    """
    Convert aggregated rows into Haystack Documents.

    - type == "text": row["content"].
    - type == "sv_code": row["content"].
    - type == "table": caption + stripped table_body_html + footnote.
      (kept even if no text; we still preserve the table record.)
    - type == "image": caption + footnote; if they are empty, we still
      keep the image by synthesizing a minimal textual content using img_path.
    """
    docs: List[Document] = []

    for row in rows:
        row = deepcopy(row)
        rtype = row.get("type", "text")

        content: str = ""
        skip_if_empty = False  # only text/sv_code are skippable when empty

        if rtype in ("text", "sv_code"):
            content = (row.pop("content", "") or "").strip()
            skip_if_empty = True

        elif rtype == "table":
            caption = (row.get("table_caption") or "").strip()
            body_html = row.get("table_body_html") or ""
            footnote = (row.get("table_footnote") or "").strip()

            body_text = html_to_text(body_html)
            pieces = [p for p in (caption, body_text, footnote) if p]
            content = "\n".join(pieces).strip()
            # For tables: if even this is empty, we still keep them.
            if not content:
                content = "[TABLE]"

        elif rtype == "image":
            caption = (row.get("image_caption") or "").strip()
            footnote = (row.get("image_footnote") or "").strip()
            img_path = row.get("img_path") or ""

            pieces = [p for p in (caption, footnote) if p]
            content = "\n".join(pieces).strip()

            # If MinerU/01_5 did not attach any caption/footnote to this image,
            # we still preserve it by synthesizing a simple textual description.
            if not content:
                label = PurePosixPath(img_path).name if img_path else ""
                content = f"[IMAGE] {label}".strip()

        else:
            # fallback: treat as generic text if content present
            content = (row.pop("content", "") or "").strip()
            skip_if_empty = True

        if not content and skip_if_empty:
            # only text/sv_code (and generic fallback) are dropped when empty
            continue

        uri = row.get("uri", "")
        default_source = PurePosixPath(uri).name if uri else ""

        meta: Dict[str, Any] = row
        meta.setdefault("source", default_source)

        doc = Document(content=content, meta=meta)
        docs.append(doc)

    return docs

# %%
# DocumentSplitter: we rely on it to chunk text, and it already
# "attaches" small chunks below split_threshold to the previous one
# rather than discarding them.

splitter = DocumentSplitter(
    split_by="word",
    split_length=240,   # target chunk size
    split_overlap=20,   # overlap between chunks
    split_threshold=50  # if a split is < 50 words, attach to previous
)

splitter
# Out:
# ...
# Inputs:
#   - documents: list[Document]
# Outputs:
#   - documents: list[Document]

# %%
def postprocess_chunks(chunk_docs: List[Document]) -> None:
    """
    Add checksum and indexed_at metadata to each chunk Document in-place.
    """
    indexed_at = datetime.now(timezone.utc).isoformat()

    for d in chunk_docs:
        if not d.content:
            continue
        d.meta["checksum"] = compute_checksum(d.content)
        # run-level timestamp
        d.meta.setdefault("indexed_at", indexed_at)


def write_docs_jsonl(docs: List[Document], path: Path) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    with path.open("w", encoding="utf-8") as f:
        for d in docs:
            # Flatten meta into top-level keys; this matches Haystack 2.x expectations.
            data = d.to_dict(flatten=True)
            f.write(json.dumps(data, ensure_ascii=False) + "\n")

# %%
def build_chunks_for_source(json_in: Path, json_out: Path) -> List[Document]:
    """
    End-to-end step 02 for a single source (Users Guide or Class Reference):

    1. Load block-level rows from 01_5 JSONL.
    2. Aggregate short text rows (type == "text") until MIN_TEXT_WORDS is reached.
    3. Convert rows to Haystack Documents (text, sv_code, table, image).
    4. Split Documents with DocumentSplitter.
    5. Add checksum/indexed_at.
    6. Write chunk-level JSONL for indexing.
    """
    print(f"[02] Loading blocks from {json_in} ...")
    rows = load_paragraph_jsonl(json_in)
    print(f"[02] Loaded {len(rows)} raw rows")

    rows_agg = aggregate_short_text_rows(rows, min_words=MIN_TEXT_WORDS)
    print(f"[02] After aggregating short text rows: {len(rows_agg)} rows")

    paragraph_docs = rows_to_paragraph_docs(rows_agg)
    print(f"[02] Converted to {len(paragraph_docs)} paragraph-level Documents")

    split_result = splitter.run(documents=paragraph_docs)
    chunk_docs: List[Document] = split_result["documents"]
    print(f"[02] Split into {len(chunk_docs)} chunk Documents")

    postprocess_chunks(chunk_docs)
    write_docs_jsonl(chunk_docs, json_out)
    print(f"[02] Wrote chunks to {json_out}")

    # quick sanity check
    if chunk_docs:
        sample = chunk_docs[0]
        print(
            "[02] Sample chunk:",
            len(chunk_docs),
            sample.meta.get("type"),
            sample.meta.get("section_title"),
            sample.meta.get("uri"),
            sample.meta.get("anchor"),
        )
    return chunk_docs

# %%
manual_chunks = build_chunks_for_source(MANUAL_JSON_IN, MANUAL_JSON_OUT)
class_chunks = build_chunks_for_source(CLASS_JSON_IN, CLASS_JSON_OUT)

len(manual_chunks), len(class_chunks)
# Out:
# [02] Loading blocks from c:\Users\41v1r\NEU\NLP\UVM-RAG\work\work_manual\json_out\uvm_users_guide_blocks_augmented.jsonl ...
# [02] Loaded 2178 raw rows
# [02] After aggregating short text rows: 1209 rows
# [02] Converted to 1209 paragraph-level Documents
# [02] Split into 1212 chunk Documents
# [02] Wrote chunks to c:\Users\41v1r\NEU\NLP\UVM-RAG\work\work_manual\json_out\uvm_users_guide_chunks.haystack.jsonl
# [02] Sample chunk: 1212 text None /pdf/uvm_users_guide_1.2.pdf #page=1
# [02] Loading blocks from c:\Users\41v1r\NEU\NLP\UVM-RAG\work\work_class_reference\json_out\uvm_class_reference_blocks_augmented.jsonl ...
# [02] Loaded 12897 raw rows
# [02] After aggregating short text rows: 5017 rows
# [02] Converted to 5017 paragraph-level Documents
# [02] Split into 5038 chunk Documents
# [02] Wrote chunks to c:\Users\41v1r\NEU\NLP\UVM-RAG\work\work_class_reference\json_out\uvm_class_reference_chunks.haystack.jsonl
# ...
